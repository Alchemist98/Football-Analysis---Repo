# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Table example - Premier league table.csv")
data.drop('Last 6',axis=1,inplace=True)

# %%
data.head()
# Out:
#    #               Team  Pl   W  D  L   F   A  GD  Pts
# 0  1          Liverpool  18  15  3  0  39   7  32   48
# 1  2    Manchester City  18  14  2  2  50  13  37   44
# 2  3  Tottenham Hotspur  18  14  0  4  37  18  19   42
# 3  4            Chelsea  18  11  4  3  35  15  20   37
# 4  5            Arsenal  18  11  4  3  40  24  16   37

# %%
plt.hlines(y=np.arange(1,21),xmin=0,xmax=data['Pts'],color="skyblue")
plt.plot(data['Pts'],np.arange(1,21), "o")
plt.yticks(np.arange(1,21),data['Team'])
plt.xlabel("Points Earned")
plt.title("Points table plot")
# Out:
# Text(0.5, 1.0, 'Points table plot')

# %%
fig,ax = plt.subplots()

teamColours = ['#034694','#001C58','#5CBFEB','#D00027',
              '#EF0107','#DA020E','#274488','#ED1A3B',
               '#000000','#091453','#60223B','#0053A0',
               '#E03A3E','#1B458F','#000000','#53162f',
               '#FBEE23','#EF6610','#C92520','#BA1F1A']

plt.hlines(y=np.arange(1,21),xmin=0,xmax=data['Pts'],color="skyblue")
plt.plot(data['Pts'],np.arange(1,21), "o")
plt.yticks(np.arange(1,21),data['Team'])
plt.xlabel("Points")
plt.title("PL Points table 18/19")


#For every side of the box, set to invisible

for side in ['right','left','top','bottom']:
    ax.spines[side].set_visible(False)
    
#Remove the ticks on the x and y axes

for tic in ax.xaxis.get_major_ticks():
    tic.tick1On = tic.tick2On = False

for tic in ax.yaxis.get_major_ticks():
    tic.tick1On = tic.tick2On = False
# Out:
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:24: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:24: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:27: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:27: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.

# %%
#Set our plot and desired size
fig = plt.figure(figsize=(10,7))
ax = plt.subplot()

teamColours = ['#034694','#001C58','#5CBFEB','#D00027',
              '#EF0107','#DA020E','#274488','#ED1A3B',
               '#000000','#091453','#60223B','#0053A0',
               '#E03A3E','#1B458F','#000000','#53162f',
               '#FBEE23','#EF6610','#C92520','#BA1F1A']

plt.hlines(y=np.arange(1,21),xmin=0,xmax=data['Pts'],color="skyblue")
plt.yticks(np.arange(1,21),data['Team'])
plt.xlabel("Points")


#For every side of the box, set to invisible

for side in ['right','left','top','bottom']:
    ax.spines[side].set_visible(False)
    
#Remove the ticks on the x and y axes

for tic in ax.xaxis.get_major_ticks():
    tic.tick1On = tic.tick2On = False

for tic in ax.yaxis.get_major_ticks():
    tic.tick1On = tic.tick2On = False

#Change font
plt.rcParams["font.family"] = "DejaVu Sans"

#Instead of use plt.title, we'll use plt.text to fully customize it
#First two arguments are x and y location
plt.text(55, 19,"Premier League 18/19", size=18, fontweight="normal")

for i, v in enumerate(data['Pts']):
    ax.text(v+2, i+0.8, str(v), color=teamColours[i], size = 13)
    
    
#Set a linewidth in our hlines argument
plt.hlines(y=np.arange(1,21),xmin=0,xmax=data['Pts'],color=teamColours,linewidths=10)

#Set a background colour to the data area background and the plot as a whole
ax.set_facecolor('#f7f4f4')
fig.patch.set_facecolor('#f7f4f4')
# Out:
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:24: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:24: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:27: MatplotlibDeprecationWarning:
# The tick1On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick1line.set_visible instead.
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:27: MatplotlibDeprecationWarning:
# The tick2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.tick2line.set_visible instead.
