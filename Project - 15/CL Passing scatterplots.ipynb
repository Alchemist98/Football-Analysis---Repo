# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("championsleague.xlsx")
data.head(10)
# Out:
#           Player    Pos                Squad  Age  90s   TCmp   Tatt  TCmp%  \
# 0  Tammy Abraham     FW          eng Chelsea   21  5.4   65.0   96.0   67.7
# 1    Tyler Adams     DF        de RB Leipzig   20  0.4   22.0   32.0   68.8
# 2   Arijan Ademi  MF,DF     hr Dinamo Zagreb   28  5.8  145.0  165.0   87.9
# 3         Adrián     GK        eng Liverpool   32  3.3   79.0   98.0   80.6
# 4  Sergio Agüero     FW  eng Manchester City   31  2.2   32.0   50.0   64.0
# 5  Manuel Akanji     DF          de Dortmund   24  5.8  342.0  388.0   88.1
# 6    David Alaba     DF     de Bayern Munich   27  3.5  264.0  296.0   89.2
# 7   Lucas Alario     FW        de Leverkusen   26  2.4   40.0   47.0   85.1
# 8     Jordi Alba     DF         es Barcelona   30  1.9  100.0  116.0   86.2
# 9   Paco Alcácer     FW          de Dortmund   25  1.3   17.0   24.0   70.8
#
#    TotDist  PrgDist  ...  LAtt  LCmp%  Ast   xA  A-xA   KP  \
# 0    982.0    133.0  ...  15.0   53.3    1  0.5   0.5  6.0
# ...

# %%
data.columns
# Out:
# Index([           'Player',               'Pos',             'Squad',
#                      'Age',               '90s',              'TCmp',
#                     'Tatt',             'TCmp%',           'TotDist',
#                  'PrgDist',              'SCmp',              'SAtt',
#                    'SCmp%',              'MCmp',              'MAtt',
#                    'MCmp%',              'LCmp',              'LAtt',
#                    'LCmp%',               'Ast',                'xA',
#                     'A-xA',                'KP', 2020-01-03 00:00:00,
#                      'PPA',             'CrsPA',              'Prog'],
#       dtype='object')

# %%
len(data)
# Out:
# 499

# %%
midfielders = data[data['Pos'] == 'MF']
midfielders.head()
# Out:
#                   Player Pos             Squad  Age  90s   TCmp   Tatt  TCmp%  \
# 10      Thiago Alcántara  MF  de Bayern Munich   28  5.5  463.0  506.0   91.5
# 12          Carles Aleñá  MF      es Barcelona   21  1.0   84.0   99.0   84.8
# 15                 Allan  MF         it Napoli   28  4.9  234.0  274.0   85.4
# 19  Éder Álvarez Balanta  MF    be Club Brugge   26  3.2  129.0  151.0   85.4
# 20         Edson Álvarez  MF           nl Ajax   21  4.2  216.0  238.0   90.8
#
#     TotDist  PrgDist  ...   LAtt  LCmp%  Ast   xA  A-xA    KP  \
# 10   9862.0   2371.0  ...  153.0   85.6    2  1.3   0.7  11.0
# 12   1464.0    452.0  ...   14.0   92.9    0  0.2  -0.2   4.0
# 15   4752.0   1323.0  ...   84.0   72.6    0  0.0   0.0   0.0
# 19   2576.0    636.0  ...   45.0   73.3    0  0.3  -0.3   4.0
# 20   3903.0   1019.0  ...   46.0   87.0    0  0.3  -0.3   2.0
#
#     2020-01-03 00:00:00  PPA  CrsPA  Prog
# 10                 62.0  8.0    0.0  45.0
# ...

# %%
len(midfielders)
# Out:
# 113

# %%
mf = midfielders[midfielders['Tatt'] >= 250]
mf.head()
# Out:
#                    Player Pos             Squad  Age  90s   TCmp   Tatt  \
# 10       Thiago Alcántara  MF  de Bayern Munich   28  5.5  463.0  506.0
# 15                  Allan  MF         it Napoli   28  4.9  234.0  274.0
# 32       Charles Aránguiz  MF     de Leverkusen   30  4.6  330.0  380.0
# 51         Wílmar Barrios  MF          ru Zenit   25  6.0  221.0  256.0
# 54  Julian Baumgartlinger  MF     de Leverkusen   31  3.8  229.0  254.0
#
#     TCmp%  TotDist  PrgDist  ...   LAtt  LCmp%  Ast   xA  A-xA    KP  \
# 10   91.5   9862.0   2371.0  ...  153.0   85.6    2  1.3   0.7  11.0
# 15   85.4   4752.0   1323.0  ...   84.0   72.6    0  0.0   0.0   0.0
# 32   86.8   5866.0   1511.0  ...   81.0   82.7    1  0.3   0.7   5.0
# 51   86.3   4021.0   1229.0  ...   61.0   82.0    0  0.0   0.0   2.0
# 54   90.2   4468.0    824.0  ...   63.0   90.5    0  0.0   0.0   1.0
#
#     2020-01-03 00:00:00  PPA  CrsPA  Prog
# 10                 62.0  8.0    0.0  45.0
# ...

# %%
mf.reset_index(drop=True,inplace=True)

# %%
mf
# Out:
#                    Player Pos                Squad  Age  90s   TCmp   Tatt  \
# 0        Thiago Alcántara  MF     de Bayern Munich   28  5.5  463.0  506.0
# 1                   Allan  MF            it Napoli   28  4.9  234.0  274.0
# 2        Charles Aránguiz  MF        de Leverkusen   30  4.6  330.0  380.0
# 3          Wílmar Barrios  MF             ru Zenit   25  6.0  221.0  256.0
# 4   Julian Baumgartlinger  MF        de Leverkusen   31  3.8  229.0  254.0
# 5            Sander Berge  MF              be Genk   21  6.0  224.0  263.0
# 6        Marcelo Brozović  MF             it Inter   26  5.8  299.0  346.0
# 7         Sergio Busquets  MF         es Barcelona   31  4.9  357.0  397.0
# 8                Casemiro  MF       es Real Madrid   27  6.7  414.0  478.0
# 9          Kerem Demirbay  MF        de Leverkusen   26  4.2  217.0  280.0
# 10            Diego Demme  MF        de RB Leipzig   27  4.0  314.0  355.0
# ...

# %%
fig = plt.figure()
fig.set_size_inches(15,10)
ax = fig.add_subplot(1,1,1)
plt.style.use('dark_background')

plt.scatter(mf['TCmp%'],mf['TCmp'],marker='D',edgecolors='face',alpha=0.7)
plt.xlabel("Total Pass Completion %",size=16)
plt.ylabel("Total Passes Completed",size=16)
plt.suptitle("Pass Completion",size=20,y=0.94)

for i,txt in enumerate(mf['Player']):
    ax.annotate(txt,(mf['TCmp%'][i],mf['TCmp'][i]))

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#plt.rcParams

# %%
fig = plt.figure()
fig.set_size_inches(15,10)
ax = fig.add_subplot(1,1,1)
plt.style.use('seaborn-bright')

plt.scatter(mf['Prog'],mf['TCmp'],marker='D',edgecolors='face',alpha=0.7)
plt.xlabel("Progressive Passes",size=16)
plt.ylabel("Total Passes Completed",size=16)
plt.suptitle("Most Progressive Passes Played",size=20,y=0.92)
#plt.text(71,435,r'Thomas Partey')

for i,txt in enumerate(mf['Player']):
    ax.annotate(txt,(mf['Prog'][i],mf['TCmp'][i]))

# %%
from adjustText import adjust_text

# %%
fig = plt.figure()
fig.set_size_inches(15,10)
ax = fig.add_subplot(1,1,1)
#plt.style.use('seaborn-bright')
plt.style.use('seaborn-talk')

plt.scatter(mf['LCmp%'],mf['LAtt'],marker='D',edgecolors='face',color='blue')
plt.xlabel("Total Long Pass Completion %",size=16)
plt.ylabel("Total Long Passes Attempted",size=16)
plt.suptitle("Long Pass Completion",size=20,y=0.92)

for i,txt in enumerate(mf['Player']):
    
    ax.annotate(txt,(mf['LCmp%'][i],mf['LAtt'][i]))

#adjust_text(txt, only_move='y', arrowprops=dict(arrowstyle="->", color='r', lw=0.5))

# %%
from adjustText import adjust_text

# %%
fig = plt.figure()
fig.set_size_inches(15,10)
ax = fig.add_subplot(1,1,1)
plt.style.use('dark_background')

#plt.scatter(mf['SCmp%'],mf['SAtt'],marker='D',edgecolors='face',alpha=0.7,color='blue')
sns.scatterplot(x='SCmp%',y='SAtt',marker='o',color='blue',data=mf,palette='deep',size='SCmp%')
plt.xlabel("Total Short Pass Completion %",size=16)
plt.ylabel("Total Short Passes Attempted",size=16)
plt.suptitle("Short Pass Completion",size=20,y=0.94)

for i,txt in enumerate(mf['Player']):
    ax.annotate(txt,(mf['SCmp%'][i],mf['SAtt'][i]),textcoords = 'offset points', ha = 'right', va = 'bottom',
                arrowprops=dict(arrowstyle="->", color='red', lw=1))
# Out:
# C:\Users\shubham\anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   from ipykernel import kernelapp as app

# %%
def get_text_positions(x_data, y_data, txt_width, txt_height):
    a = zip(y_data, x_data)
    text_positions = y_data.copy()
    for index, (y, x) in enumerate(a):
        local_text_positions = [i for i in a if i[0] > (y - txt_height)
                            and (abs(i[1] - x) < txt_width * 2) and i != (y,x)]
        if local_text_positions:
            sorted_ltp = sorted(local_text_positions)
            if abs(sorted_ltp[0][0] - y) < txt_height: #True == collision
                differ = np.diff(sorted_ltp, axis=0)
                a[index] = (sorted_ltp[-1][0] + txt_height, a[index][1])
                text_positions[index] = sorted_ltp[-1][0] + txt_height
                for k, (j, m) in enumerate(differ):
                    #j is the vertical distance between words
                    if j > txt_height * 1.5: #if True then room to fit a word in
                        a[index] = (sorted_ltp[k][0] + txt_height, a[index][1])
                        text_positions[index] = sorted_ltp[k][0] + txt_height
                        break
    return text_positions

# %%
def text_plotter(x_data, y_data, text_positions, axis,txt_width,txt_height):
    for x,y,t in zip(x_data, y_data, text_positions):
        axis.text(x - .03, 1.02*t, '%d'%int(y),rotation=0, color='blue', fontsize=13)
        if y != t:
            axis.arrow(x, t+20,0,y-t, color='blue',alpha=0.2, width=txt_width*0.0,
                       head_width=.02, head_length=txt_height*0.5,
                       zorder=0,length_includes_head=True)
x_data = mf['SCmp%']
y_data = mf['SAtt']

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
plt.scatter(x_data, y_data, alpha = 0.4)
txt_height = 0.04*(plt.ylim()[1] - plt.ylim()[0])
txt_width = 0.02*(plt.xlim()[1] - plt.xlim()[0])
text_positions = get_text_positions(x_data, y_data, txt_width, txt_height)
text_plotter(x_data, y_data, text_positions, ax, txt_width, txt_height)

plt.ylim(0,3610)
plt.xlim(4.3,6.5)

#periscope.output(plt)
# Out:
# (4.3, 6.5)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-91312ccc6d66> in <module>
#      13 plt.xlim(4.3,6.5)
#      14
# ---> 15 periscope.output(plt)
#
# NameError: name 'periscope' is not defined
